# %%
import numpy as np
import time

# %%
python_list = [1,2,3,4,5,6]

# %%
# Creating Numpy Array
arr = np.array(python_list)

# %%
print(type(arr))

# %%
py_list = list(range(1_000_000_0))
np_array = np.arange(1_000_000_0)

# %%
# Measuring performance

# # For python List
start = time.time()
squares = [x*x for x in py_list]
end = time.time()

print(f"python List Timing : {end - start} seconds")

# For Numpay Array

start = time.time()
sq = np.square(np_array)
end = time.time()
print(f"Numpy Array Timing : {end - start} seconds")

# %%
# Measuring Memory
import sys

print(f"Pyhton List size : {sys.getsizeof(py_list) * len(py_list)}")
print(f"numpy Array size : {np_array.nbytes}")
# Out:
# Pyhton List size : 800000560000000
# numpy Array size : 80000000
